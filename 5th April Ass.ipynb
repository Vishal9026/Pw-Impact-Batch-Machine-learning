# %% [markdown]
# # Q1. Import the dataset and examine the variables. Use descriptive statistics and visualizations to understand the distribution and relationships between the variables.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
df["Glucose"]=df["Glucose"].replace(0,df["Glucose"].mean())
df["BloodPressure"]=df["BloodPressure"].replace(0,df["BloodPressure"].mean())
df["SkinThickness"]=df["SkinThickness"].replace(0,df["SkinThickness"].mean())
df["Insulin"]=df["Insulin"].replace(0,df["Insulin"].mean())
df["BMI"]=df["BMI"].replace(0,df["BMI"].mean())

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %%
df.hist(figsize=(10, 10))
plt.show()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.127964       0.208984       0.013376
# Glucose                      0.127964  1.000000       0.219666       0.160766
# BloodPressure                0.208984  0.219666       1.000000       0.134155
# SkinThickness                0.013376  0.160766       0.134155       1.000000
# Insulin                     -0.018082  0.396597       0.010926       0.240361
# BMI                          0.021546  0.231478       0.281231       0.535703
# DiabetesPedigreeFunction    -0.033523  0.137106       0.000371       0.154961
# Age                          0.544341  0.266600       0.326740       0.026423
# Outcome                      0.221898  0.492908       0.162986       0.175026
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.021546                 -0.033523
# ...

# %% [markdown]
# # Q2. Preprocess the data by cleaning missing values, removing outliers, and transforming categorical variables into dummy variables if necessary.

# %%
plt.subplots(figsize=(15, 5))
sns.boxplot(df)
# Out:
# <AxesSubplot: >

# %%
from scipy import stats

z_scores = stats.zscore(df)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df = df[filtered_entries]

# %%
plt.subplots(figsize=(15, 5))
sns.boxplot(df)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Q3. Split the dataset into a training set and a test set. Use a random seed to ensure reproducibility.

# %%
# #independent features
# X=df.iloc[:,:-1]
# #dependent features
# y=df.iloc[:,-1]
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 5              5    116.0           74.0      20.536458   79.799479  25.6
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Q4. Use a decision tree algorithm, such as ID3 or C4.5, to train a decision tree model on the training set. Use cross-validation to optimize the hyperparameters and avoid overfitting.

# %%
from sklearn.tree import DecisionTreeClassifier
treeclassifier  = DecisionTreeClassifier()
treeclassifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree

plt.figure(figsize = (25,10))
tree.plot_tree(treeclassifier,filled = True)
# Out:
# [Text(0.5340221774193549, 0.96875, 'x[1] <= 143.5\ngini = 0.458\nsamples = 481\nvalue = [310, 171]'),
#  Text(0.2145497311827957, 0.90625, 'x[5] <= 27.35\ngini = 0.379\nsamples = 374\nvalue = [279, 95]'),
#  Text(0.021505376344086023, 0.84375, 'x[1] <= 106.5\ngini = 0.075\nsamples = 102\nvalue = [98, 4]'),
#  Text(0.010752688172043012, 0.78125, 'gini = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(0.03225806451612903, 0.78125, 'x[4] <= 49.0\ngini = 0.147\nsamples = 50\nvalue = [46, 4]'),
#  Text(0.021505376344086023, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.043010752688172046, 0.71875, 'x[5] <= 25.55\ngini = 0.115\nsamples = 49\nvalue = [46, 3]'),
#  Text(0.03225806451612903, 0.65625, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.053763440860215055, 0.65625, 'x[2] <= 66.0\ngini = 0.236\nsamples = 22\nvalue = [19, 3]'),
#  Text(0.03225806451612903, 0.59375, 'x[0] <= 2.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
# ...

# %%
# Post Pruning
treeclassifier  = DecisionTreeClassifier(max_depth=3)
treeclassifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
from sklearn import tree

plt.figure(figsize = (25,10))
tree.plot_tree(treeclassifier,filled = True)
# Out:
# [Text(0.5, 0.875, 'x[1] <= 143.5\ngini = 0.458\nsamples = 481\nvalue = [310, 171]'),
#  Text(0.25, 0.625, 'x[5] <= 27.35\ngini = 0.379\nsamples = 374\nvalue = [279, 95]'),
#  Text(0.125, 0.375, 'x[1] <= 106.5\ngini = 0.075\nsamples = 102\nvalue = [98, 4]'),
#  Text(0.0625, 0.125, 'gini = 0.0\nsamples = 52\nvalue = [52, 0]'),
#  Text(0.1875, 0.125, 'gini = 0.147\nsamples = 50\nvalue = [46, 4]'),
#  Text(0.375, 0.375, 'x[1] <= 99.5\ngini = 0.445\nsamples = 272\nvalue = [181, 91]'),
#  Text(0.3125, 0.125, 'gini = 0.202\nsamples = 79\nvalue = [70, 9]'),
#  Text(0.4375, 0.125, 'gini = 0.489\nsamples = 193\nvalue = [111, 82]'),
#  Text(0.75, 0.625, 'x[1] <= 154.5\ngini = 0.412\nsamples = 107\nvalue = [31, 76]'),
#  Text(0.625, 0.375, 'x[1] <= 153.0\ngini = 0.498\nsamples = 34\nvalue = [16, 18]'),
#  Text(0.5625, 0.125, 'gini = 0.48\nsamples = 30\nvalue = [12, 18]'),
#  Text(0.6875, 0.125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
# ...

# %%
y_pred = treeclassifier.predict(X_test)

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {"criterion":["gini","entropy","log_loss"],
            "splitter":["best","random"],
             "max_depth":[1,2,3,4,5],
             "max_features":["auto","sqrt","log2"]
            }

# %%
treeclassifier = DecisionTreeClassifier()
clf = GridSearchCV(treeclassifier,param_grid=parameter,cv = 5,scoring = "accuracy")

# %%
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
clf.best_params_
# Out:
# {'criterion': 'log_loss',
#  'max_depth': 4,
#  'max_features': 'log2',
#  'splitter': 'random'}

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# # Q5. Evaluate the performance of the decision tree model on the test set using metrics such as accuracy,precision, recall, and F1 score. Use confusion matrices and ROC curves to visualize the results.

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score = accuracy_score(y_pred,y_test)
print(score)
print(classification_report(y_pred,y_test))
# Out:
# 0.7763713080168776
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85       197
#            1       0.41      0.72      0.52        40
#
#     accuracy                           0.78       237
#    macro avg       0.67      0.76      0.69       237
# weighted avg       0.85      0.78      0.80       237

# %%
score = accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.7257383966244726

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.82       189
#            1       0.38      0.56      0.45        48
#
#     accuracy                           0.73       237
#    macro avg       0.63      0.66      0.64       237
# weighted avg       0.77      0.73      0.74       237

# %% [markdown]
# # Q6. Interpret the decision tree by examining the splits, branches, and leaves. Identify the most important variables and their thresholds. Use domain knowledge and common sense to explain the patterns and trends.

# %% [markdown]
# Based on this decision tree, we can conclude that glucose, BMI, and age are the most important variables for identifying patients with diabetes. Patients with high glucose levels, high BMI, and/or older age are more likely to have diabetes. This is consistent with domain knowledge and common sense, as these are all well-known risk factors for diabetes.
#
# It's worth noting that this decision tree may not be the most accurate or comprehensive model for identifying patients with diabetes, as it only considers a limited set of clinical variables. Other models may be able to achieve higher accuracy by including additional variables or using more advanced techniques. Nonetheless, this decision tree provides a useful starting point for identifying patients at risk of diabetes based on readily available clinical data.

# %% [markdown]
# # Q7. Validate the decision tree model by applying it to new data or testing its robustness to changes in the dataset or the environment. Use sensitivity analysis and scenario testing to explore the uncertainty and risks.

# %% [markdown]
# However, in general, validating a decision tree model involves applying the model to new data to see how well it performs. This can be done by splitting the original dataset into a training set and a test set, fitting the decision tree model to the training set, and then evaluating its performance on the test set. This can help to identify whether the model is overfitting or underfitting the data.
#
# Sensitivity analysis and scenario testing can also be used to explore the uncertainty and risks associated with the decision tree model. Sensitivity analysis involves varying the inputs to the model to see how sensitive the outputs are to changes in the inputs. This can help to identify which variables are most important and which have the greatest impact on the model's predictions.
#
# Scenario testing involves testing the model under different scenarios or conditions to see how well it performs. For example, the decision tree model could be tested on data from different geographic regions or on data from patients with different demographic characteristics to see if the model's performance varies.
#
# Overall, validating a decision tree model is an important step in ensuring that it is accurate and reliable. It is important to carefully test and validate the model using a variety of methods to ensure that it performs well under a range of conditions and is robust to changes in the dataset or the environment.
